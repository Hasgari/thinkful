# %%
import pandas as pd
import numpy as np
from sklearn import linear_model
import statsmodels.formula.api as smf
from statsmodels.sandbox.regression.predstd import wls_prediction_std

# %%
df = pd.read_csv("reg_features.csv")

# %%
df.shape[0]
# Out:
# 351

# %%
list(df.columns)
# Out:
# ['Unnamed: 0',
#  'City',
#  'Population',
#  'Violent\ncrime',
#  'Murder and\nnonnegligent\nmanslaughter',
#  'Rape\n(revised\ndefinition)1',
#  'Rape\n(legacy\ndefinition)2',
#  'Robbery',
#  'Aggravated\nassault',
#  'Property\ncrime',
#  'Burglary',
#  'Larceny-\ntheft',
#  'Motor\nvehicle\ntheft',
#  'Arson3',
#  'Unnamed: 13',
#  'Robbery_dummy',
#  'Murder',
#  'Population_squared']

# %%
regr = linear_model.LinearRegression()
df.columns
df_model = df.loc[:,[var for var in list(df.columns)if (var != "Unnamed: 13" and var != "Unnamed: 0" and var != "Rape\n(revised\ndefinition)1" )]]
df_model = df_model.dropna()
print(df_model.shape[0])
y = df_model["Property\ncrime"]
#x = df_model[[var for var in list(df_model.columns)if (var != "City" and var != "Property\ncrime" and var != "Murder" and var != "Robbery_dummy" and var != "Population" and var != "Population_squared" and var != "Larceny-\ntheft")]]
#x = df_model[["Burglary","Arson3"]]
x = df_model[["Larceny-\ntheft","Burglary","Arson3"]]
regr.fit(x, y)
print(regr.coef_)
print(regr.intercept_)
print(regr.score(x, y))
# Out:
# 187
# [1.00672825 1.18661361 0.60392136]
# -1.1079757338685567
# 0.9998131005568379

# %%
df_model.corr()
# Out:
#                                         Population  Violent\ncrime  \
# Population                                1.000000        0.842771
# Violent\ncrime                            0.842771        1.000000
# Murder and\nnonnegligent\nmanslaughter    0.721619        0.935035
# Rape\n(legacy\ndefinition)2               0.778008        0.941682
# Robbery                                   0.825202        0.991514
# Aggravated\nassault                       0.849594        0.994766
# Property\ncrime                           0.869461        0.928742
# Burglary                                  0.798252        0.951748
# Larceny-\ntheft                           0.882745        0.901060
# Motor\nvehicle\ntheft                     0.850976        0.983210
# Arson3                                    0.701761        0.917793
# Robbery_dummy                             0.387305        0.216225
# Murder                                    0.558612        0.501509
# Population_squared                        0.915519        0.903374
#
#                                         Murder and\nnonnegligent\nmanslaughter  \
# Population                                                            0.721619
# Violent\ncrime                                                        0.935035
# Murder and\nnonnegligent\nmanslaughter                                1.000000
# Rape\n(legacy\ndefinition)2                                           0.928107
# Robbery                                                               0.952565
# Aggravated\nassault                                                   0.903082
# Property\ncrime                                                       0.900364
# Burglary                                                              0.938292
# Larceny-\ntheft                                                       0.867897
# Motor\nvehicle\ntheft                                                 0.953407
# Arson3                                                                0.963200
# Robbery_dummy                                                         0.159119
# Murder                                                                0.449768
# Population_squared                                                    0.804753
#
#                                         Rape\n(legacy\ndefinition)2   Robbery  \
# Population                                                 0.778008  0.825202
# Violent\ncrime                                             0.941682  0.991514
# Murder and\nnonnegligent\nmanslaughter                     0.928107  0.952565
# Rape\n(legacy\ndefinition)2                                1.000000  0.922612
# Robbery                                                    0.922612  1.000000
# Aggravated\nassault                                        0.934009  0.973815
# Property\ncrime                                            0.938082  0.917779
# Burglary                                                   0.967139  0.939902
# Larceny-\ntheft                                            0.910984  0.889972
# Motor\nvehicle\ntheft                                      0.958307  0.979517
# Arson3                                                     0.926301  0.931607
# Robbery_dummy                                              0.220834  0.202660
# Murder                                                     0.459615  0.470085
# Population_squared                                         0.821880  0.902455
#
#                                         Aggravated\nassault  Property\ncrime  \
# Population                                         0.849594         0.869461
# Violent\ncrime                                     0.994766         0.928742
# Murder and\nnonnegligent\nmanslaughter             0.903082         0.900364
# Rape\n(legacy\ndefinition)2                        0.934009         0.938082
# Robbery                                            0.973815         0.917779
# Aggravated\nassault                                1.000000         0.919836
# Property\ncrime                                    0.919836         1.000000
# Burglary                                           0.942082         0.977555
# Larceny-\ntheft                                    0.892867         0.995724
# Motor\nvehicle\ntheft                              0.970778         0.957595
# Arson3                                             0.888278         0.920765
# Robbery_dummy                                      0.223805         0.307479
# Murder                                             0.520828         0.502598
# Population_squared                                 0.897319         0.839382
#
#                                         Burglary  Larceny-\ntheft  \
# Population                              0.798252         0.882745
# Violent\ncrime                          0.951748         0.901060
# Murder and\nnonnegligent\nmanslaughter  0.938292         0.867897
# Rape\n(legacy\ndefinition)2             0.967139         0.910984
# Robbery                                 0.939902         0.889972
# Aggravated\nassault                     0.942082         0.892867
# Property\ncrime                         0.977555         0.995724
# Burglary                                1.000000         0.954354
# Larceny-\ntheft                         0.954354         1.000000
# Motor\nvehicle\ntheft                   0.972423         0.933414
# Arson3                                  0.952121         0.893610
# Robbery_dummy                           0.241905         0.333036
# Murder                                  0.478224         0.505925
# Population_squared                      0.811245         0.831597
#
#                                         Motor\nvehicle\ntheft    Arson3  \
# Population                                           0.850976  0.701761
# Violent\ncrime                                       0.983210  0.917793
# Murder and\nnonnegligent\nmanslaughter               0.953407  0.963200
# Rape\n(legacy\ndefinition)2                          0.958307  0.926301
# Robbery                                              0.979517  0.931607
# Aggravated\nassault                                  0.970778  0.888278
# Property\ncrime                                      0.957595  0.920765
# Burglary                                             0.972423  0.952121
# Larceny-\ntheft                                      0.933414  0.893610
# Motor\nvehicle\ntheft                                1.000000  0.935194
# Arson3                                               0.935194  1.000000
# Robbery_dummy                                        0.226041  0.165537
# Murder                                               0.472164  0.367961
# Population_squared                                   0.892558  0.784309
#
#                                         Robbery_dummy    Murder  \
# Population                                   0.387305  0.558612
# Violent\ncrime                               0.216225  0.501509
# Murder and\nnonnegligent\nmanslaughter       0.159119  0.449768
# Rape\n(legacy\ndefinition)2                  0.220834  0.459615
# Robbery                                      0.202660  0.470085
# Aggravated\nassault                          0.223805  0.520828
# Property\ncrime                              0.307479  0.502598
# Burglary                                     0.241905  0.478224
# Larceny-\ntheft                              0.333036  0.505925
# Motor\nvehicle\ntheft                        0.226041  0.472164
# Arson3                                       0.165537  0.367961
# Robbery_dummy                                1.000000  0.353780
# Murder                                       0.353780  1.000000
# Population_squared                           0.192749  0.430721
#
#                                         Population_squared
# Population                                        0.915519
# Violent\ncrime                                    0.903374
# Murder and\nnonnegligent\nmanslaughter            0.804753
# Rape\n(legacy\ndefinition)2                       0.821880
# Robbery                                           0.902455
# Aggravated\nassault                               0.897319
# Property\ncrime                                   0.839382
# Burglary                                          0.811245
# Larceny-\ntheft                                   0.831597
# Motor\nvehicle\ntheft                             0.892558
# Arson3                                            0.784309
# Robbery_dummy                                     0.192749
# Murder                                            0.430721
# Population_squared                                1.000000

# %%
df_model.corr()
# Out:
#                                         Population  Violent\ncrime  \
# Population                                1.000000        0.842771
# Violent\ncrime                            0.842771        1.000000
# Murder and\nnonnegligent\nmanslaughter    0.721619        0.935035
# Rape\n(legacy\ndefinition)2               0.778008        0.941682
# Robbery                                   0.825202        0.991514
# Aggravated\nassault                       0.849594        0.994766
# Property\ncrime                           0.869461        0.928742
# Burglary                                  0.798252        0.951748
# Larceny-\ntheft                           0.882745        0.901060
# Motor\nvehicle\ntheft                     0.850976        0.983210
# Arson3                                    0.701761        0.917793
# Robbery_dummy                             0.387305        0.216225
# Murder                                    0.558612        0.501509
# Population_squared                        0.915519        0.903374
#
#                                         Murder and\nnonnegligent\nmanslaughter  \
# Population                                                            0.721619
# Violent\ncrime                                                        0.935035
# Murder and\nnonnegligent\nmanslaughter                                1.000000
# Rape\n(legacy\ndefinition)2                                           0.928107
# Robbery                                                               0.952565
# Aggravated\nassault                                                   0.903082
# Property\ncrime                                                       0.900364
# Burglary                                                              0.938292
# Larceny-\ntheft                                                       0.867897
# Motor\nvehicle\ntheft                                                 0.953407
# Arson3                                                                0.963200
# Robbery_dummy                                                         0.159119
# Murder                                                                0.449768
# Population_squared                                                    0.804753
#
#                                         Rape\n(legacy\ndefinition)2   Robbery  \
# Population                                                 0.778008  0.825202
# Violent\ncrime                                             0.941682  0.991514
# Murder and\nnonnegligent\nmanslaughter                     0.928107  0.952565
# Rape\n(legacy\ndefinition)2                                1.000000  0.922612
# Robbery                                                    0.922612  1.000000
# Aggravated\nassault                                        0.934009  0.973815
# Property\ncrime                                            0.938082  0.917779
# Burglary                                                   0.967139  0.939902
# Larceny-\ntheft                                            0.910984  0.889972
# Motor\nvehicle\ntheft                                      0.958307  0.979517
# Arson3                                                     0.926301  0.931607
# Robbery_dummy                                              0.220834  0.202660
# Murder                                                     0.459615  0.470085
# Population_squared                                         0.821880  0.902455
#
#                                         Aggravated\nassault  Property\ncrime  \
# Population                                         0.849594         0.869461
# Violent\ncrime                                     0.994766         0.928742
# Murder and\nnonnegligent\nmanslaughter             0.903082         0.900364
# Rape\n(legacy\ndefinition)2                        0.934009         0.938082
# Robbery                                            0.973815         0.917779
# Aggravated\nassault                                1.000000         0.919836
# Property\ncrime                                    0.919836         1.000000
# Burglary                                           0.942082         0.977555
# Larceny-\ntheft                                    0.892867         0.995724
# Motor\nvehicle\ntheft                              0.970778         0.957595
# Arson3                                             0.888278         0.920765
# Robbery_dummy                                      0.223805         0.307479
# Murder                                             0.520828         0.502598
# Population_squared                                 0.897319         0.839382
#
#                                         Burglary  Larceny-\ntheft  \
# Population                              0.798252         0.882745
# Violent\ncrime                          0.951748         0.901060
# Murder and\nnonnegligent\nmanslaughter  0.938292         0.867897
# Rape\n(legacy\ndefinition)2             0.967139         0.910984
# Robbery                                 0.939902         0.889972
# Aggravated\nassault                     0.942082         0.892867
# Property\ncrime                         0.977555         0.995724
# Burglary                                1.000000         0.954354
# Larceny-\ntheft                         0.954354         1.000000
# Motor\nvehicle\ntheft                   0.972423         0.933414
# Arson3                                  0.952121         0.893610
# Robbery_dummy                           0.241905         0.333036
# Murder                                  0.478224         0.505925
# Population_squared                      0.811245         0.831597
#
#                                         Motor\nvehicle\ntheft    Arson3  \
# Population                                           0.850976  0.701761
# Violent\ncrime                                       0.983210  0.917793
# Murder and\nnonnegligent\nmanslaughter               0.953407  0.963200
# Rape\n(legacy\ndefinition)2                          0.958307  0.926301
# Robbery                                              0.979517  0.931607
# Aggravated\nassault                                  0.970778  0.888278
# Property\ncrime                                      0.957595  0.920765
# Burglary                                             0.972423  0.952121
# Larceny-\ntheft                                      0.933414  0.893610
# Motor\nvehicle\ntheft                                1.000000  0.935194
# Arson3                                               0.935194  1.000000
# Robbery_dummy                                        0.226041  0.165537
# Murder                                               0.472164  0.367961
# Population_squared                                   0.892558  0.784309
#
#                                         Robbery_dummy    Murder  \
# Population                                   0.387305  0.558612
# Violent\ncrime                               0.216225  0.501509
# Murder and\nnonnegligent\nmanslaughter       0.159119  0.449768
# Rape\n(legacy\ndefinition)2                  0.220834  0.459615
# Robbery                                      0.202660  0.470085
# Aggravated\nassault                          0.223805  0.520828
# Property\ncrime                              0.307479  0.502598
# Burglary                                     0.241905  0.478224
# Larceny-\ntheft                              0.333036  0.505925
# Motor\nvehicle\ntheft                        0.226041  0.472164
# Arson3                                       0.165537  0.367961
# Robbery_dummy                                1.000000  0.353780
# Murder                                       0.353780  1.000000
# Population_squared                           0.192749  0.430721
#
#                                         Population_squared
# Population                                        0.915519
# Violent\ncrime                                    0.903374
# Murder and\nnonnegligent\nmanslaughter            0.804753
# Rape\n(legacy\ndefinition)2                       0.821880
# Robbery                                           0.902455
# Aggravated\nassault                               0.897319
# Property\ncrime                                   0.839382
# Burglary                                          0.811245
# Larceny-\ntheft                                   0.831597
# Motor\nvehicle\ntheft                             0.892558
# Arson3                                            0.784309
# Robbery_dummy                                     0.192749
# Murder                                            0.430721
# Population_squared                                1.000000

# %%
x.describe()
# Out:
#        Violent\ncrime  Murder and\nnonnegligent\nmanslaughter  \
# count      187.000000                              187.000000
# mean        45.978610                                0.566845
# std        201.362989                                3.552914
# min          0.000000                                0.000000
# 25%          1.000000                                0.000000
# 50%          4.000000                                0.000000
# 75%         17.000000                                0.000000
# max       2107.000000                               42.000000
#
#        Rape\n(legacy\ndefinition)2     Robbery  Aggravated\nassault  \
# count                   187.000000  187.000000           187.000000
# mean                      2.192513   16.556150            26.663102
# std                       9.124901   81.476501           109.234772
# min                       0.000000    0.000000             0.000000
# 25%                       0.000000    0.000000             0.000000
# 50%                       0.000000    1.000000             3.000000
# 75%                       1.000000    4.000000            11.000000
# max                      92.000000  918.000000          1055.000000
#
#           Burglary  Larceny-\ntheft  Motor\nvehicle\ntheft      Arson3
# count   187.000000       187.000000             187.000000  187.000000
# mean     65.037433       260.871658              13.914439    1.871658
# std     242.693164       675.898585              57.360520   10.693411
# min       0.000000         0.000000               0.000000    0.000000
# 25%       3.000000        16.000000               0.000000    0.000000
# 50%      11.000000        62.000000               2.000000    0.000000
# 75%      39.000000       240.500000               5.000000    1.000000
# max    2587.000000      6855.000000             609.000000  132.000000
